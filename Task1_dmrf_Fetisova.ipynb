# %% [markdown]
# <a href="https://colab.research.google.com/github/Fet-elena/proba/blob/main/Task1_dmrf_Fetisova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pytosha/new-python-repo/blob/main/HomeTask/Task1_dmrf.ipynb)

# %% [markdown]
# # Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# # Задание посложнее (опциональное, если очень хочется)
# * Написать скрипт, который скачивает фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
import requests

# %% [markdown]
# ## Шаг 1й - Получение списка объектов

# %%
# Для скачивания данных

offset_ = 1 # размер шага
limit_ = 100 # количество объектов в выдаче
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')
# Out:
# [{'hobjId': 37219,
#   'objId': 13391,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 5776,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#   'objFloorMin': 3,
#   'objFloorMax': 12,
#   'objElemLivingCnt': 44,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 4343.9,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 57.1541,
#   'longitude': 65.5595,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000096',
#   'pdId': 28101,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ABFF857E1B4D64D0497FB96C782D40FEE',
#   'objPriceAVG': 62638,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 39024,
#   'objId': 13383,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 5776,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#   'objFloorMin': 4,
#   'objFloorMax': 20,
#   'objElemLivingCnt': 68,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 6423.85,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 57.1519,
#   'longitude': 65.5536,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000095',
#   'pdId': 28105,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A7DA9AAFAA1F245B09666D97D31445BA1',
#   'objPriceAVG': 66773,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 37165,
#   'objId': 13398,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 5776,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#   'objFloorMin': 7,
#   'objFloorMax': 10,
#   'objElemLivingCnt': 43,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 4812.98,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 57.1519,
#   'longitude': 65.5544,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000097',
#   'pdId': 28141,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A12ECBF4F0CAE418BA061ABE999561FDD',
#   'objPriceAVG': 47886,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 37201,
#   'objId': 13397,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 5776,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#   'objFloorMin': 6,
#   'objFloorMax': 12,
#   'objElemLivingCnt': 65,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 6251.1,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 57.1519,
#   'longitude': 65.5544,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000097',
#   'pdId': 28141,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AA65FDD2568DB4A839F677DFF0EA805A6',
#   'objPriceAVG': 47163,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 6541,
#   'objId': 10891,
#   'developer': {'devId': 3006,
#    'shortName': 'ААК ВОЛОГДААГРОСТРОЙ',
#    'fullName': 'АКЦИОНЕРНАЯ АГРОСТРОИТЕЛЬНАЯ КОМПАНИЯВОЛОГДААГРОСТРОЙ',
#    'groupName': 'ВологдаАгрострой',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 7368,
#    'devInn': '3525000888'},
#   'rpdRegionCd': 35,
#   'objAddr': 'г Вологда, ул Медуницинская, д. 11',
#   'objCommercNm': 'Жилой комплекс "Рафинад"',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 225,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 12847.23,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 59.1985,
#   'longitude': 39.858,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '35-000069',
#   'pdId': 23054,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A834123CBB81F44529F3C3ED599D48484',
#   'objPriceAVG': 47684,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 136720,
#   'objId': 56006,
#   'developer': {'devId': 3980,
#    'shortName': 'АВАЛОН',
#    'fullName': 'АВАЛОН',
#    'groupName': 'Дельта Девелопмент',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6230,
#    'devInn': '5408001391'},
#   'rpdRegionCd': 54,
#   'objAddr': 'город Новосибирск, район Советский',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 24,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 1003.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.9071,
#   'longitude': 83.117,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '54-002047',
#   'pdId': 795065,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A8BA97A85783F49949C7940D56397B383',
#   'objPublDt': '2023-12-01'},
#  {'hobjId': 115751,
#   'objId': 30292,
#   'developer': {'devId': 7699,
#    'shortName': 'АВАЛОН СИТИ',
#    'fullName': 'АВАЛОН СИТИ',
#    'groupName': 'Спектр-М',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7451,
#    'devInn': '1655297266'},
#   'rpdRegionCd': 16,
#   'objAddr': 'г Казань, район Приволжский р-н, ул Карбышева',
#   'objFloorMin': 26,
#   'objFloorMax': 26,
#   'objElemLivingCnt': 384,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 30373.74,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.7523,
#   'longitude': 49.1671,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '16-000988',
#   'pdId': 120396,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AAF33C7684DCB4E2F865A60561968973E',
#   'objPriceAVG': 108320,
#   'objPublDt': '2020-05-12'},
#  {'hobjId': 36235,
#   'objId': 18708,
#   'developer': {'devId': 3812,
#    'shortName': 'АВИГРАН',
#    'fullName': 'АВИГРАН',
#    'groupName': 'АВИГРАН',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 9119,
#    'devInn': '7722264703'},
#   'rpdRegionCd': 50,
#   'objAddr': 'г Лыткарино, мкр 6-й, корпус 4',
#   'objCommercNm': 'Жилой комплекс "Новое Лыткарино"',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 272,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 12057.8,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 55.5972,
#   'longitude': 37.8822,
#   'complexShortName': 'ЖК Новое Лыткарино',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '50-000877',
#   'pdId': 44330,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AD2F8C8ADD0464C569AC593ACE2D684DA',
#   'objPriceAVG': 100727,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 26010,
#   'objId': 18709,
#   'developer': {'devId': 3812,
#    'shortName': 'АВИГРАН',
#    'fullName': 'АВИГРАН',
#    'groupName': 'АВИГРАН',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 9119,
#    'devInn': '7722264703'},
#   'rpdRegionCd': 50,
#   'objAddr': 'г Лыткарино, мкр 6-й, корпус 3',
#   'objCommercNm': 'Жилой комплекс "Новое Лыткарино"',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 272,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 12093.84,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 55.5974,
#   'longitude': 37.8831,
#   'complexShortName': 'ЖК Новое Лыткарино',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '50-000877',
#   'pdId': 44330,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A93C399E9A3FB4BFDB7D8C6F4B5110260',
#   'objPriceAVG': 95270,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42916,
#   'objId': 27803,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'п Ложок',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8421,
#   'longitude': 83.179,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000833',
#   'pdId': 98026,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A094BD07061B94EC389090F98BC33FC9E',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42886,
#   'objId': 23862,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'с/с Барышевский, д. 56/148 (внутренний)',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 6,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 787.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8414,
#   'longitude': 83.1761,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000693',
#   'pdId': 43156,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A863DB60F1C49427493779B7B8D8D80F2',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42738,
#   'objId': 27798,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'п Ложок',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8422,
#   'longitude': 83.1789,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000833',
#   'pdId': 98026,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AC08AEE834B2842B79A803532307EF90E',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42895,
#   'objId': 27801,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'п Ложок',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8464,
#   'longitude': 83.1788,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000833',
#   'pdId': 98026,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AB5F39711CC9E4621B739787F2633326A',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42915,
#   'objId': 27802,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'п Ложок',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8414,
#   'longitude': 83.1788,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000833',
#   'pdId': 98026,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A4659A61A311D443BAE28F31770002820',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42900,
#   'objId': 23864,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'с/с Барышевский',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8414,
#   'longitude': 83.1788,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000693',
#   'pdId': 43156,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AC4479D4A791249D48DB52A5C42495634',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 42343,
#   'objId': 23863,
#   'developer': {'devId': 1297,
#    'shortName': 'АКАДЕМПАРК',
#    'fullName': 'АКЦИОНЕРНОЕ ОБЩЕСТВО ТЕХНОПАРК НОВОСИБИРСКОГО АКАДЕМГОРОДКА',
#    'groupName': 'Технопарк Новосибирского Академгородка',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 6767,
#    'devInn': '5408252116'},
#   'rpdRegionCd': 54,
#   'objAddr': 'с/с Барышевский',
#   'objCommercNm': 'Коттеджный поселок "Горки Академпарка"',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 889.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.8421,
#   'longitude': 83.1789,
#   'complexShortName': 'Коттеджный поселок Горки Академпарка',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '54-000693',
#   'pdId': 43156,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A2A656D82FF814C9EB717958FBD3B2F44',
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 125859,
#   'objId': 45249,
#   'developer': {'devId': 6270,
#    'shortName': 'АКВАТОРИЯ',
#    'fullName': 'АКВАТОРИЯ',
#    'groupName': 'Wainbridge',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 9251,
#    'devInn': '7712006051'},
#   'rpdRegionCd': 77,
#   'objAddr': 'г Москва, ш Ленинградское, вл. 69',
#   'objCommercNm': 'Многофункциональный комплекс AQUATORIA (корпуса A1 A2)',
#   'objFloorMin': 2,
#   'objFloorMax': 23,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.8701,
#   'longitude': 37.4566,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '77-002435',
#   'pdId': 530733,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A03FD45EEA17C4D11B0FD7FE6CF577876',
#   'objPriceAVG': 231772,
#   'objPublDt': '2022-02-25'},
#  {'hobjId': 130150,
#   'objId': 49511,
#   'developer': {'devId': 226,
#    'shortName': 'АКД-МЕТА',
#    'fullName': 'АКД-МЕТА',
#    'groupName': 'АКД',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7279,
#    'devInn': '5405416327'},
#   'rpdRegionCd': 54,
#   'objAddr': 'г Новосибирск, район Октябрьский р-н, ул Лескова, д. 29а',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.0229,
#   'longitude': 82.9538,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '54-001839',
#   'pdId': 668440,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AF30B8948F6414512A8FB930E001771EA',
#   'objPriceAVG': 45452,
#   'objPublDt': '2022-12-13'},
#  {'hobjId': 131056,
#   'objId': 50412,
#   'developer': {'devId': 8672,
#    'shortName': 'АЛЕКС-СТРОЙ',
#    'fullName': 'АЛЕКС-СТРОЙ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5410007680'},
#   'rpdRegionCd': 54,
#   'objAddr': 'г Новосибирск, район Калининский р-н, ул Курчатова, д. 1/2, корпус 1',
#   'objCommercNm': 'Семиэтажный гаражный комплекс со станцией технического обслуживания и автомойкой',
#   'objFloorMin': 2,
#   'objFloorMax': 2,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.1066,
#   'longitude': 82.9605,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '54-001877',
#   'pdId': 437975,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A841FBA50BAAC4BF8A188872B74F89954',
#   'objPublDt': '2023-02-07'},
#  {'hobjId': 131057,
#   'objId': 50411,
#   'developer': {'devId': 8672,
#    'shortName': 'АЛЕКС-СТРОЙ',
#    'fullName': 'АЛЕКС-СТРОЙ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5410007680'},
#   'rpdRegionCd': 54,
#   'objAddr': 'г Новосибирск, район Калининский р-н, ул Курчатова, д. 1/2',
#   'objCommercNm': 'Семиэтажный гаражный комплекс со станцией технического обслуживания и автомойкой',
#   'objFloorMin': 7,
#   'objFloorMax': 7,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.1058,
#   'longitude': 82.9601,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '54-001877',
#   'pdId': 437975,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643ADAC49DC4670545799BD73E49BA3263BB',
#   'objPublDt': '2023-02-07'},
#  {'hobjId': 135418,
#   'objId': 54731,
#   'developer': {'devId': 17129,
#    'shortName': 'АЛЕКССТРОЙ',
#    'fullName': 'АЛЕКССТРОЙ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '0814155998'},
#   'rpdRegionCd': 8,
#   'objAddr': 'город Элиста',
#   'objFloorMin': 3,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 12,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 1273.57,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 46.3123,
#   'longitude': 44.3106,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '08-000059',
#   'pdId': 773741,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A02BDB02511C64BC093292AAB13463877',
#   'objPublDt': '2023-10-06'},
#  {'hobjId': 135543,
#   'objId': 54856,
#   'developer': {'devId': 17129,
#    'shortName': 'АЛЕКССТРОЙ',
#    'fullName': 'АЛЕКССТРОЙ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '0814155998'},
#   'rpdRegionCd': 8,
#   'objAddr': 'город Элиста, пр-кт Имени Петра Анацкого, д. 18, вл. дом',
#   'objFloorMin': 4,
#   'objFloorMax': 6,
#   'objElemLivingCnt': 57,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 3328.47,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 46.3121,
#   'longitude': 44.3112,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '08-000060',
#   'pdId': 778221,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A28B22A781FE94A8C8B98A50857973824',
#   'objPublDt': '2023-10-10'},
#  {'hobjId': 44649,
#   'objId': 33745,
#   'developer': {'devId': 8792,
#    'shortName': 'АЛТПРОМСНАБ',
#    'fullName': 'АЛТПРОМСНАБ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '2223032641'},
#   'rpdRegionCd': 22,
#   'objAddr': 'г Барнаул, ул Власихинская, д. 156А',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 53.3289,
#   'longitude': 83.6819,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 0,
#   'rpdNum': '22-000306',
#   'pdId': 212271,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AE1854F6C661847D0BCCCFA8FFA1AE423',
#   'objPriceAVG': 16438,
#   'objPublDt': '2019-10-17'},
#  {'hobjId': 133364,
#   'objId': 52663,
#   'developer': {'devId': 9770,
#    'shortName': 'АЛЬГЕБА',
#    'fullName': 'АЛЬГЕБА',
#    'groupName': 'Сибирьинвест',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6104,
#    'devInn': '5407025216'},
#   'rpdRegionCd': 54,
#   'objAddr': 'г Новосибирск, ул Фабричная',
#   'objFloorMin': 30,
#   'objFloorMax': 30,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-06-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.0271,
#   'longitude': 82.8961,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '54-001954',
#   'pdId': 734536,
#   'buildType': 'Нежилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643ACCF1AFC0938649B88AD13E16916732E3',
#   'objPublDt': '2023-06-20'},
#  {'hobjId': 130446,
#   'objId': 49802,
#   'developer': {'devId': 9770,
#    'shortName': 'АЛЬГЕБА',
#    'fullName': 'АЛЬГЕБА',
#    'groupName': 'Сибирьинвест',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6104,
#    'devInn': '5407025216'},
#   'rpdRegionCd': 54,
#   'objAddr': 'г Новосибирск, ул Фабричная, блок-секция 3.2',
#   'objCommercNm': 'Жилой Комплекс "Чернышевский"',
#   'objFloorMin': 31,
#   'objFloorMax': 31,
#   'objElemLivingCnt': 275,
#   'objReady100PercDt': '2025-03-31',
#   'objSquareLiving': 11239.45,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.027,
#   'longitude': 82.8959,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '54-001846',
#   'pdId': 671023,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ADEA5500C445842D59ACB9BD9D7402E80',
#   'objPriceAVG': 157035,
#   'objPublDt': '2022-12-28'},
#  {'hobjId': 115219,
#   'objId': 35324,
#   'developer': {'devId': 4475,
#    'shortName': 'АЛЬПИК',
#    'fullName': 'АЛЬПИК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '7708533009',
#    'bankruptStage': {'bankruptStageCd': 6,
#     'bankruptStageDesc': 'Сообщение о судебном акте. О прекращении производства по делу или об отказе в признании должника банкротом',
#     'bankruptLawUrl': 'http://www.consultant.ru/document/cons_doc_LAW_39331/97e3783dff35e269cd1c6d35cbabfa4abee6fd37/'},
#    'orgBankruptMsgDttm': '28-12-2020 16:29'},
#   'rpdRegionCd': 23,
#   'objAddr': 'г Сочи, ул Краевско-Греческая',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 114,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 6343.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 43.5796,
#   'longitude': 39.7888,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '23-002003',
#   'pdId': 290662,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643ADA37D1667C3B48A892BC267E5F32CDAB',
#   'objPriceAVG': 45598,
#   'objPublDt': '2020-03-27'},
#  {'hobjId': 122147,
#   'objId': 41619,
#   'developer': {'devId': 7040,
#    'shortName': 'АЛЬФА',
#    'fullName': 'АЛЬФА',
#    'groupName': 'AVA Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6695,
#    'devInn': '2312233660'},
#   'rpdRegionCd': 23,
#   'objAddr': 'п Знаменский, литера 8',
#   'objCommercNm': 'ЖК "СМОРОДИНА"',
#   'objFloorMin': 14,
#   'objFloorMax': 14,
#   'objElemLivingCnt': 120,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 5472.48,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 45.0599,
#   'longitude': 39.1119,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '23-002366',
#   'pdId': 472265,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A492B9922AF14496FA40C85C0BA872C3D',
#   'objPriceAVG': 135888,
#   'objPublDt': '2021-07-08'},
#  {'hobjId': 122145,
#   'objId': 41621,
#   'developer': {'devId': 7040,
#    'shortName': 'АЛЬФА',
#    'fullName': 'АЛЬФА',
#    'groupName': 'AVA Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6695,
#    'devInn': '2312233660'},
#   'rpdRegionCd': 23,
#   'objAddr': 'п Знаменский, литера 10',
#   'objCommercNm': 'ЖК "СМОРОДИНА"',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 64,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 4032.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 45.0605,
#   'longitude': 39.113,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '23-002366',
#   'pdId': 472265,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AD1D33AF17FCA4D33917C869E4C71C316',
#   'objPriceAVG': 117612,
#   'objPublDt': '2021-07-08'},
#  {'hobjId': 122148,
#   'objId': 41618,
#   'developer': {'devId': 7040,
#    'shortName': 'АЛЬФА',
#    'fullName': 'АЛЬФА',
#    'groupName': 'AVA Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6695,
#    'devInn': '2312233660'},
#   'rpdRegionCd': 23,
#   'objAddr': 'п Знаменский, литера 7',
#   'objCommercNm': 'ЖК "СМОРОДИНА"',
#   'objFloorMin': 14,
#   'objFloorMax': 14,
#   'objElemLivingCnt': 360,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 16417.44,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 45.0587,
#   'longitude': 39.1119,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '23-002366',
#   'pdId': 472265,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A38376C090F614743A1B9968A5F07C0D2',
#   'objPriceAVG': 138134,
#   'objPublDt': '2021-07-08'},
#  {'hobjId': 122146,
#   'objId': 41620,
#   'developer': {'devId': 7040,
#    'shortName': 'АЛЬФА',
#    'fullName': 'АЛЬФА',
#    'groupName': 'AVA Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6695,
#    'devInn': '2312233660'},
#   'rpdRegionCd': 23,
#   'objAddr': 'п Знаменский, литера 9',
#   'objCommercNm': 'ЖК "СМОРОДИНА"',
#   'objFloorMin': 14,
#   'objFloorMax': 14,
#   'objElemLivingCnt': 96,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 6048.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 45.0605,
#   'longitude': 39.1121,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '23-002366',
#   'pdId': 472265,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AB493418A1B164078B45417A97F38812C',
#   'objPriceAVG': 120123,
#   'objPublDt': '2021-07-08'},
#  {'hobjId': 20249,
#   'objId': 18136,
#   'developer': {'devId': 6193,
#    'shortName': 'АЛЬЯНС',
#    'fullName': 'АЛЬЯНС',
#    'groupName': 'Альянс',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 9176,
#    'devInn': '6312173063'},
#   'rpdRegionCd': 63,
#   'objAddr': 'г Самара',
#   'objFloorMin': 27,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 360,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 20664.24,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 53.2056,
#   'longitude': 50.2144,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '63-000283',
#   'pdId': 43084,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A343DFB296F5D4550A40FAD7C63DAD453',
#   'objPriceAVG': 46899,
#   'objPublDt': '2019-05-31'},
#  {'hobjId': 134459,
#   'objId': 53791,
#   'developer': {'devId': 13654,
#    'shortName': 'АЛЬЯНС-БРИЛЛ',
#    'fullName': 'АЛЬЯНС-БРИЛЛ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3906341911'},
#   'rpdRegionCd': 39,
#   'objAddr': 'г Зеленоградск, ул Солнечная',
#   'objFloorMin': 7,
#   'objFloorMax': 7,
#   'objElemLivingCnt': 80,
#   'objReady100PercDt': '2026-12-31',
#   'objSquareLiving': 5187.72,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.957,
#   'longitude': 20.4882,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '39-001354',
#   'pdId': 758816,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643AE1D86522257248569E767CB856287B18',
#   'objPublDt': '2023-08-21'},
#  {'hobjId': 132931,
#   'objId': 52284,
#   'developer': {'devId': 134,
#    'shortName': 'АО СЗ ИПОТЕЧНАЯ КОРПОРАЦИЯ РБ ИЛИ АО СЗ ИК РБ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ИПОТЕЧНАЯ КОРПОРАЦИЯ РЕСПУБЛИКИ БУРЯТИЯ',
#    'groupName': 'Ипотечная корпорация Республики Бурятия',
#    'orgForm': {'id': 3,
#     'fullForm': 'Непубличное акционерное общество',
#     'shortForm': 'АО'},
#    'companyGroup': 5735,
#    'devInn': '0326012555'},
#   'rpdRegionCd': 3,
#   'objAddr': 'мкр 140А, район Октябрьский р-н, д. 42',
#   'objFloorMin': 10,
#   'objFloorMax': 13,
#   'objElemLivingCnt': 92,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 5490.32,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.8008,
#   'longitude': 107.6803,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '03-000238',
#   'pdId': 726492,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643ACFEFB62A3A414409A81283763293C9E6',
#   'objPublDt': '2023-06-02'},
#  {'hobjId': 44006,
#   'objId': 33168,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 74',
#   'objCommercNm': 'Березовый квартал, дом 74',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 36,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2268.08,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4999,
#   'longitude': 36.9313,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AD0DA50F16DD74365A220F2442682A38D',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43973,
#   'objId': 33135,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 41',
#   'objCommercNm': 'Сиреневый квартал, дом 41',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 75,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 3280.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4866,
#   'longitude': 36.9197,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A0D6F2CAD614F4D718C4D061B00EFB576',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44069,
#   'objId': 33231,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 137',
#   'objCommercNm': 'Рябиновый квартал, дом 137',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5038,
#   'longitude': 36.9341,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A465AE76A57B44399992E24BBA5E3FEEC',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44033,
#   'objId': 33195,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 101',
#   'objCommercNm': 'Рябиновый квартал, дом 101',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 39,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 2278.61,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5054,
#   'longitude': 36.933,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A641DCD9DBFA2416D99937670D748B1F0',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43989,
#   'objId': 33151,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 57',
#   'objCommercNm': 'Березовый квартал, дом 57',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 75,
#   'objReady100PercDt': '2024-06-30',
#   'objSquareLiving': 3280.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.502,
#   'longitude': 36.9301,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A3ECDAA1072A84533BB30F8B2A9337AD7',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44038,
#   'objId': 33200,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 106',
#   'objCommercNm': 'Рябиновый квартал, дом 106',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 39,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 2278.61,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5048,
#   'longitude': 36.9351,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ACBA80CCAE6F24A3297FD6180DC92FCC1',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43982,
#   'objId': 33144,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 50',
#   'objCommercNm': 'Березовый квартал, дом 50',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5027,
#   'longitude': 36.9296,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A090B67D942884CC9BA7E263E39A3784E',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44019,
#   'objId': 33181,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 87',
#   'objCommercNm': 'Рябиновый квартал, дом 87',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.506,
#   'longitude': 36.9337,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AE797DEF7946B4A8EB2642F00261C382B',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44004,
#   'objId': 33166,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 72',
#   'objCommercNm': 'Березовый квартал, дом 72',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 36,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 2268.08,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4994,
#   'longitude': 36.9306,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ABD0EFF210BCF474595BCF192D5FE4ED8',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43997,
#   'objId': 33159,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 65',
#   'objCommercNm': 'Березовый квартал, дом 65',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2024-09-30',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4981,
#   'longitude': 36.9287,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AAF22E5E4ADF74DD2ACF51DF0E82E028A',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43991,
#   'objId': 33153,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 59',
#   'objCommercNm': 'Березовый квартал, дом 59',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2024-09-30',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.501,
#   'longitude': 36.9323,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AF7D0299D3D56498E854ADF9CB63B15A4',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44052,
#   'objId': 33214,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 120',
#   'objCommercNm': 'Рябиновый квартал, дом 120',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 2198.66,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5052,
#   'longitude': 36.9307,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A6FE6D2A5C0ED4BDE817237EC175D04FD',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44059,
#   'objId': 33221,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 127',
#   'objCommercNm': 'Рябиновый квартал, дом 127',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 30,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1097.08,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5045,
#   'longitude': 36.9333,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A02C7A3EB0F804795B52D105A90584A81',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44063,
#   'objId': 33225,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 131',
#   'objCommercNm': 'Рябиновый квартал, дом 131',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 30,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1097.08,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5042,
#   'longitude': 36.9348,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A1316ACF6979B43519523A34FE6F836F4',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44066,
#   'objId': 33228,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 134',
# ...
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 68',
#   'objCommercNm': 'Березовый квартал, дом 68',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 48,
#   'objReady100PercDt': '2024-12-31',
#   'objSquareLiving': 2164.28,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4986,
#   'longitude': 36.9294,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AC7DA5E3AD4204CD68C6AD828E572577A',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44032,
#   'objId': 33194,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 100',
#   'objCommercNm': 'Рябиновый квартал, дом 100',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 2198.66,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5056,
#   'longitude': 36.9333,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A402DEBEFBD454C7DAF6587FCB62CABEA',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44026,
#   'objId': 33188,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 94',
#   'objCommercNm': 'Рябиновый квартал, дом 94',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5063,
#   'longitude': 36.931,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A0A4EC47F7C9E49DE9B33F75EC80C4E46',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44002,
#   'objId': 33164,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 70',
#   'objCommercNm': 'Березовый квартал, дом 70',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 78,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 4557.22,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.499,
#   'longitude': 36.9301,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A61DC48F626E54E1C876AFAA7E0C5D70C',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44001,
#   'objId': 33163,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 69',
#   'objCommercNm': 'Березовый квартал, дом 69',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2198.66,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4988,
#   'longitude': 36.9298,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ACF1E3575B34E45F3AAA3992FA4CFE7A4',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44029,
#   'objId': 33191,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 97',
#   'objCommercNm': 'Рябиновый квартал, дом 97',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.506,
#   'longitude': 36.932,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AF12A320E99844A68A4C3049236F1F726',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44045,
#   'objId': 33207,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 113',
#   'objCommercNm': 'Рябиновый квартал, дом 113',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5054,
#   'longitude': 36.9321,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AB90544B2C7644283B6B0E3FB27017A6A',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44016,
#   'objId': 33178,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 84',
#   'objCommercNm': 'Рябиновый квартал, дом 84',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5055,
#   'longitude': 36.9347,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A78D69790ACE942529655946F3495FD5B',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44011,
#   'objId': 33173,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 79',
#   'objCommercNm': 'Березовый квартал, дом 79',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 2198.66,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5007,
#   'longitude': 36.9327,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A6880E1A9001040C9A3C39DB6204776DF',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44030,
#   'objId': 33192,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 98',
#   'objCommercNm': 'Рябиновый квартал, дом 98',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 39,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 2278.61,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5058,
#   'longitude': 36.9326,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A88EC3320A85247D58B37A6D7D141D83B',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44058,
#   'objId': 33220,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 126',
#   'objCommercNm': 'Рябиновый квартал, дом 126',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 30,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1097.08,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5046,
#   'longitude': 36.9329,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A6A3EA6568B5C4DF79DBCFB7ED2C0FE14',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44003,
#   'objId': 33165,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 71',
#   'objCommercNm': 'Березовый квартал, дом 71',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 60,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 3423.18,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4993,
#   'longitude': 36.9304,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A688AFE06046F4A849562D88AF688C41C',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 43994,
#   'objId': 33156,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 62',
#   'objCommercNm': 'Березовый квартал, дом 62',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2024-09-30',
#   'objSquareLiving': 2198.66,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.4975,
#   'longitude': 36.9279,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AC53F3D68DF924EE79599ED0C599C506E',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44047,
#   'objId': 33209,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 115',
#   'objCommercNm': 'Рябиновый квартал, дом 115',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5056,
#   'longitude': 36.9313,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3AEFFEAE6F660642E99663B02E322A423D',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44048,
#   'objId': 33210,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 116',
#   'objCommercNm': 'Рябиновый квартал, дом 116',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 18,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1026.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5057,
#   'longitude': 36.9309,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ADC6CF54FAD124DBCADA46450F9F2300F',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44068,
#   'objId': 33230,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 136',
#   'objCommercNm': 'Рябиновый квартал, дом 136',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1017.17,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5037,
#   'longitude': 36.9344,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A5BED80424A524F03BE359632BE9AF9F7',
#   'objPublDt': '2019-09-02'},
#  {'hobjId': 44025,
#   'objId': 33187,
#   'developer': {'devId': 3522,
#    'shortName': 'АПРЕЛЕВКА С2',
#    'fullName': 'АПРЕЛЕВКА С2',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5030049041'},
#   'rpdRegionCd': 77,
#   'objAddr': 'д Зверево, д. 93',
#   'objCommercNm': 'Рябиновый квартал, дом 93',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 24,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 1082.14,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.5065,
#   'longitude': 36.9313,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '77-001887',
#   'pdId': 77853,
#   'buildType': 'Жилое',
#   'objStatus': 0,
#   'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A211BFF78C072469AAE8089385343D602',
#   'objPublDt': '2019-09-02'}]

# %%
objects_data.keys()
# Out:
# dict_keys(['data', 'errcode'])

# %%
a = objects_data.get('data')
type(a)
a.keys()
# Out:
# dict_keys(['list', 'total'])

# %%
a.get('list')
type(a.get('list'))
# Out:
# list

# %%
import pandas as pd
df = pd.DataFrame(objects_data.get('data').get('list'))
df_stroj = df[df.siteStatus == 'Строящиеся']
df_stroj
# Out:
#     hobjId  objId                                          developer  \
# 0    37219  13391  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 1    39024  13383  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 2    37165  13398  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 3    37201  13397  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 4     6541  10891  {'devId': 3006, 'shortName': 'ААК ВОЛОГДААГРОС...
# ..     ...    ...                                                ...
# 95   43994  33156  {'devId': 3522, 'shortName': 'АПРЕЛЕВКА С2', '...
# 96   44047  33209  {'devId': 3522, 'shortName': 'АПРЕЛЕВКА С2', '...
# 97   44048  33210  {'devId': 3522, 'shortName': 'АПРЕЛЕВКА С2', '...
# 98   44068  33230  {'devId': 3522, 'shortName': 'АПРЕЛЕВКА С2', '...
# 99   44025  33187  {'devId': 3522, 'shortName': 'АПРЕЛЕВКА С2', '...
#
#     rpdRegionCd                             objAddr  objFloorMin  objFloorMax  \
# 0            72     г Тюмень, ул Профсоюзная, д. 56            3           12
# 1            72     г Тюмень, ул Профсоюзная, д. 56            4           20
# 2            72     г Тюмень, ул Профсоюзная, д. 56            7           10
# 3            72     г Тюмень, ул Профсоюзная, д. 56            6           12
# 4            35  г Вологда, ул Медуницинская, д. 11           17           17
# ..          ...                                 ...          ...          ...
# 95           77                    д Зверево, д. 62            3            3
# 96           77                   д Зверево, д. 115            3            3
# 97           77                   д Зверево, д. 116            3            3
# 98           77                   д Зверево, д. 136            3            3
# 99           77                    д Зверево, д. 93            3            3
#
#     objElemLivingCnt objReady100PercDt  objSquareLiving  ...  \
# 0                 44        2023-12-31          4343.90  ...
# 1                 68        2023-12-31          6423.85  ...
# 2                 43        2024-12-31          4812.98  ...
# 3                 65        2024-12-31          6251.10  ...
# 4                225        2023-12-31         12847.23  ...
# ..               ...               ...              ...  ...
# 95                51        2024-09-30          2198.66  ...
# 96                18        2023-12-31          1026.64  ...
# 97                18        2023-12-31          1026.64  ...
# 98                23        2023-12-31          1017.17  ...
# 99                24        2023-12-31          1082.14  ...
#
#     residentialBuildings     rpdNum   pdId  buildType objStatus  \
# 0                      1  72-000096  28101      Жилое         0
# 1                      1  72-000095  28105      Жилое         0
# 2                      1  72-000097  28141      Жилое         0
# 3                      1  72-000097  28141      Жилое         0
# 4                      1  35-000069  23054      Жилое         0
# ..                   ...        ...    ...        ...       ...
# 95                     1  77-001887  77853      Жилое         0
# 96                     1  77-001887  77853      Жилое         0
# 97                     1  77-001887  77853      Жилое         0
# 98                     1  77-001887  77853      Жилое         0
# 99                     1  77-001887  77853      Жилое         0
#
#                                    hobjRenderPhotoUrl  objPriceAVG  \
# 0   https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...      62638.0
# 1   https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...      66773.0
# 2   https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...      47886.0
# 3   https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...      47163.0
# 4   https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...      47684.0
# ..                                                ...          ...
# 95  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...          NaN
# 96  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...          NaN
# 97  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...          NaN
# 98  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...          NaN
# 99  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...          NaN
#
#      objPublDt                objCommercNm  complexShortName
# 0   2019-05-31                         NaN               NaN
# 1   2019-05-31                         NaN               NaN
# 2   2019-05-31                         NaN               NaN
# 3   2019-05-31                         NaN               NaN
# 4   2019-05-31    Жилой комплекс "Рафинад"               NaN
# ..         ...                         ...               ...
# 95  2019-09-02   Березовый квартал, дом 62               NaN
# 96  2019-09-02  Рябиновый квартал, дом 115               NaN
# 97  2019-09-02  Рябиновый квартал, дом 116               NaN
# 98  2019-09-02  Рябиновый квартал, дом 136               NaN
# 99  2019-09-02   Рябиновый квартал, дом 93               NaN
#
# [100 rows x 27 columns]

# %%
df_stroj.to_excel ('stroj.xlsx')
